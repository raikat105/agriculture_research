# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping

sns.set_theme(style="whitegrid", palette="viridis")

# %%
try:
    data = pd.read_csv("sample_data/bankura_wheat_detailed.csv")
    print("✅ Dataset loaded successfully!")
    display(data.head())
except FileNotFoundError:
    print("❌ Error: CSV not found.")
# Out:
# ✅ Dataset loaded successfully!
#    Year District  Wheat_Yield_t_ha  year  week_1_precip  week_1_LST  \
# 0  2001  Bankura             2.425  2001       0.000000   30.205143
# 1  2002  Bankura             2.470  2002       0.003000   29.035714
# 2  2003  Bankura             2.582  2003       0.000000   27.376286
# 3  2004  Bankura             2.688  2004       0.004571   27.358286
# 4  2005  Bankura             2.648  2005       0.009714   27.176143
#
#    week_2_precip  week_2_LST  week_3_precip  week_3_LST  ...  \
# 0       0.000000   29.356571            0.0   26.550571  ...
# 1       0.000000   27.504571            0.0   26.874571  ...
# 2       0.000000   27.356571            0.0   26.379143  ...
# 3       0.000429   26.208143            0.0   25.116571  ...
# 4       0.000000   27.300429            0.0   26.503714  ...
#
#    fortnight_7_precip  fortnight_7_LST  fortnight_8_precip  fortnight_8_LST  \
# 0            0.000000        30.830929            1.479643        31.752143
# 1            0.495214        28.736929            0.441286        32.055286
# 2            0.561214        26.870357            0.000000        30.876857
# 3            0.051214        28.055214            0.000500        33.127643
# 4            1.336500        29.370714            0.056000        31.440429
#
#    fortnight_9_precip  fortnight_9_LST  fortnight_10_precip  fortnight_10_LST  \
# 0            0.000000        36.067286             2.765214         34.706714
# 1            0.771071        34.149000             0.925786         19.060929
# 2            4.167000        30.839071             0.067786         32.530429
# 3            0.022143        34.405071             1.806857         36.295714
# 4            2.330786        33.169857             0.781714         33.096429
#
#    fortnight_11_precip  fortnight_11_LST
# 0             0.743833         35.792083
# 1             0.960583         33.695417
# 2             1.760750         34.737500
# 3             2.129846         34.975538
# 4             0.438750         35.231917
#
# [5 rows x 70 columns]

# %%
TARGET = "Wheat_Yield_t_ha"

exclude_cols = ["Year", "District", TARGET, "year"]

feature_cols = [col for col in data.columns if col not in exclude_cols]

print(f"Identified {len(feature_cols)} feature columns.")
feature_cols
# Out:
# Identified 66 feature columns.
# ['week_1_precip',
#  'week_1_LST',
#  'week_2_precip',
#  'week_2_LST',
#  'week_3_precip',
#  'week_3_LST',
#  'week_4_precip',
#  'week_4_LST',
#  'week_5_precip',
#  'week_5_LST',
#  'week_6_precip',
#  'week_6_LST',
#  'week_7_precip',
#  'week_7_LST',
#  'week_8_precip',
#  'week_8_LST',
#  'week_9_precip',
#  'week_9_LST',
#  'week_10_precip',
#  'week_10_LST',
#  'week_11_precip',
#  'week_11_LST',
#  'week_12_precip',
#  'week_12_LST',
#  'week_13_precip',
#  'week_13_LST',
#  'week_14_precip',
#  'week_14_LST',
#  'week_15_precip',
#  'week_15_LST',
#  'week_16_precip',
#  'week_16_LST',
#  'week_17_precip',
#  'week_17_LST',
#  'week_18_precip',
#  'week_18_LST',
#  'week_19_precip',
#  'week_19_LST',
#  'week_20_precip',
#  'week_20_LST',
#  'week_21_precip',
#  'week_21_LST',
#  'week_22_precip',
#  'week_22_LST',
#  'fortnight_1_precip',
#  'fortnight_1_LST',
#  'fortnight_2_precip',
#  'fortnight_2_LST',
#  'fortnight_3_precip',
#  'fortnight_3_LST',
#  'fortnight_4_precip',
#  'fortnight_4_LST',
#  'fortnight_5_precip',
#  'fortnight_5_LST',
#  'fortnight_6_precip',
#  'fortnight_6_LST',
#  'fortnight_7_precip',
#  'fortnight_7_LST',
#  'fortnight_8_precip',
#  'fortnight_8_LST',
#  'fortnight_9_precip',
#  'fortnight_9_LST',
#  'fortnight_10_precip',
#  'fortnight_10_LST',
#  'fortnight_11_precip',
#  'fortnight_11_LST']

# %%
original_features = feature_cols.copy()

weeks = sorted(list(set([
    int(col.split('_')[1]) for col in feature_cols if "week_" in col
])))

num_weeks = len(weeks)
print(f"Detected {num_weeks} weeks.")

# FIX: explicitly set features per week
features_per_week = 2
print(f"Detected {features_per_week} features per week.")

X_seq = []

for _, row in data.iterrows():
    seq = []
    for w in weeks:
        seq.append([
            row[f"week_{w}_precip"],
            row[f"week_{w}_LST"]
        ])
    X_seq.append(seq)

X_seq = np.array(X_seq)
y = data[TARGET].values

print("Final CNN input shape:", X_seq.shape)
# Out:
# Detected 22 weeks.
# Detected 2 features per week.
# Final CNN input shape: (24, 22, 2)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_seq, y, test_size=0.2, random_state=42
)

scaler = StandardScaler()

X_train_r = X_train.reshape(-1, features_per_week)
X_test_r  = X_test.reshape(-1, features_per_week)

scaler.fit(X_train_r)

X_train_scaled = scaler.transform(X_train_r).reshape(X_train.shape)
X_test_scaled  = scaler.transform(X_test_r).reshape(X_test.shape)

print("Scaling completed.")
# Out:
# Scaling completed.

# %%
print("X_train_scaled shape:", X_train_scaled.shape)
print("X_test_scaled shape:", X_test_scaled.shape)
# Out:
# X_train_scaled shape: (19, 22, 2)
# X_test_scaled shape: (5, 22, 2)

# %%
model = Sequential([

    Conv1D(filters=64, kernel_size=2, activation='relu',
           input_shape=(num_weeks, features_per_week)),
    MaxPooling1D(pool_size=2),

    Conv1D(filters=32, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=2),

    Flatten(),

    Dense(64, activation='relu'),
    Dropout(0.3),

    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 21, 64)         │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 9, 32)          │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 4, 32)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,817 (57.88 KB)
#  Trainable params: 14,817 (57.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stop = EarlyStopping(
    patience=10,
    restore_best_weights=True,
    monitor='val_loss',
    mode='min'
)

history = model.fit(
    X_train_scaled,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 7.2633 - mae: 2.6832 - val_loss: 6.1503 - val_mae: 2.4552
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 6.4728 - mae: 2.5309 - val_loss: 5.8633 - val_mae: 2.3986
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 6.0903 - mae: 2.4583 - val_loss: 5.6107 - val_mae: 2.3469
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 5.7022 - mae: 2.3778 - val_loss: 5.3362 - val_mae: 2.2884
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 5.3679 - mae: 2.3067 - val_loss: 5.0537 - val_mae: 2.2242
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 4.8943 - mae: 2.1999 - val_loss: 4.7713 - val_mae: 2.1580
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 4.8212 - mae: 2.1752 - val_loss: 4.5000 - val_mae: 2.0923
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 4.6597 - mae: 2.1471 - val_loss: 4.2462 - val_mae: 2.0287
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 4.1158 - mae: 2.0087 - val_loss: 3.9595 - val_mae: 1.9550
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 3.9155 - mae: 1.9597 - val_loss: 3.6525 - val_mae: 1.8737
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 3.4767 - mae: 1.8376 - val_loss: 3.3251 - val_mae: 1.7834
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 3.0332 - mae: 1.7164 - val_loss: 2.9604 - val_mae: 1.6769
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 2.4753 - mae: 1.5405 - val_loss: 2.5776 - val_mae: 1.5566
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 2.2134 - mae: 1.4742 - val_loss: 2.1775 - val_mae: 1.4195
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.8552 - mae: 1.2902 - val_loss: 1.7736 - val_mae: 1.2643
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 1.6705 - mae: 1.2431 - val_loss: 1.3801 - val_mae: 1.0910
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 1.4860 - mae: 1.1287 - val_loss: 1.0134 - val_mae: 0.8992
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 1.1083 - mae: 0.9678 - val_loss: 0.6981 - val_mae: 0.7370
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - loss: 0.7719 - mae: 0.7284 - val_loss: 0.4645 - val_mae: 0.6451
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.7394 - mae: 0.7695 - val_loss: 0.3344 - val_mae: 0.5503
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.9376 - mae: 0.8438 - val_loss: 0.3149 - val_mae: 0.4577
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.4800 - mae: 0.5413 - val_loss: 0.3894 - val_mae: 0.4567
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.6745 - mae: 0.6250 - val_loss: 0.5027 - val_mae: 0.5258
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.7956 - mae: 0.6884 - val_loss: 0.6107 - val_mae: 0.5897
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 1.3174 - mae: 0.8825 - val_loss: 0.6402 - val_mae: 0.6038
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 1.0910 - mae: 0.7298 - val_loss: 0.6095 - val_mae: 0.5864
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5823 - mae: 0.5354 - val_loss: 0.5564 - val_mae: 0.5564
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.9180 - mae: 0.7226 - val_loss: 0.4760 - val_mae: 0.5085
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5633 - mae: 0.5589 - val_loss: 0.3922 - val_mae: 0.4506
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.4773 - mae: 0.5490 - val_loss: 0.3255 - val_mae: 0.3932
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.7117 - mae: 0.6980 - val_loss: 0.2708 - val_mae: 0.3513
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.4473 - mae: 0.4371 - val_loss: 0.2378 - val_mae: 0.3795
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4032 - mae: 0.5673 - val_loss: 0.2230 - val_mae: 0.4092
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.3449 - mae: 0.5136 - val_loss: 0.2216 - val_mae: 0.4316
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2249 - mae: 0.3948 - val_loss: 0.2264 - val_mae: 0.4482
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.3365 - mae: 0.5095 - val_loss: 0.2328 - val_mae: 0.4587
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2666 - mae: 0.4230 - val_loss: 0.2376 - val_mae: 0.4639
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.4445 - mae: 0.5375 - val_loss: 0.2368 - val_mae: 0.4617
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.6257 - mae: 0.7061 - val_loss: 0.2314 - val_mae: 0.4541
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3636 - mae: 0.5260 - val_loss: 0.2229 - val_mae: 0.4425
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2233 - mae: 0.4001 - val_loss: 0.2138 - val_mae: 0.4293
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.1996 - mae: 0.4031 - val_loss: 0.2032 - val_mae: 0.4123
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3425 - mae: 0.4968 - val_loss: 0.1931 - val_mae: 0.3932
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.2287 - mae: 0.4313 - val_loss: 0.1833 - val_mae: 0.3695
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.1101 - mae: 0.2442 - val_loss: 0.1768 - val_mae: 0.3628
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0890 - mae: 0.2408 - val_loss: 0.1749 - val_mae: 0.3631
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.1900 - mae: 0.3646 - val_loss: 0.1787 - val_mae: 0.3640
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2996 - mae: 0.4025 - val_loss: 0.1862 - val_mae: 0.3640
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.1719 - mae: 0.3457 - val_loss: 0.1941 - val_mae: 0.3641
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.1890 - mae: 0.3627 - val_loss: 0.1998 - val_mae: 0.3644
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.1427 - mae: 0.2922 - val_loss: 0.2090 - val_mae: 0.3647
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.2134 - mae: 0.3589 - val_loss: 0.2199 - val_mae: 0.3645
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2004 - mae: 0.3478 - val_loss: 0.2259 - val_mae: 0.3646
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.1392 - mae: 0.3071 - val_loss: 0.2292 - val_mae: 0.3649
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.2694 - mae: 0.4338 - val_loss: 0.2253 - val_mae: 0.3653
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.1987 - mae: 0.3566 - val_loss: 0.2139 - val_mae: 0.3657

# %%
loss, mae = model.evaluate(X_test_scaled, y_test, verbose=0)

print("\n📈 CNN Evaluation Results:")
print(f"MAE: {mae:.4f}")

y_pred = model.predict(X_test_scaled, verbose=0)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MSE: {mse:.4f}")
print(f"R2 Score: {r2:.4f}")

plt.figure(figsize=(8,5))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Actual vs Predicted Wheat Yield (CNN)")
plt.show()
# Out:
# 📈 CNN Evaluation Results:
# MAE: 0.5115
# MSE: 0.7099
# R2 Score: -13.1074
